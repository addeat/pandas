# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from matplotlib import font_manager, rc

font_path = './malgun.ttf'
font_name = font_manager.FontProperties(fname = font_path).get_name()
rc('font', family = font_name)

# %%
df = pd.read_csv('./auto-mpg.csv', header = None)
df.columns = ['mpg','cylinders','displacement','horsepower','weight',
              'acceleration','model year','origin','name']

# %%
plt.style.use('classic')
df['mpg'].plot(kind = 'hist', bins = 10 , color = 'coral', figsize = (10, 5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
## 선점도  상곤관계를 확인하기 위해 많이 구림
df.plot(kind = 'scatter', x = 'weight', y = 'mpg')
# Out:
# <AxesSubplot:xlabel='weight', ylabel='mpg'>

# %%
df['count'] = 1
df
df_origin = df_origin('origin').sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20672\1756223517.py in <module>
#       1 df['count'] = 1
#       2 df
# ----> 3 df_origin = df_origin('origin').sum()
#
# TypeError: 'DataFrame' object is not callable

# %%
df['count'] = 1
df_origin.index = ['USA','EU',' JPN']

df_origin['count'].plot(kind = 'pie', figsize = (7, 5), autopct = '%1.1f%%', startangle = 10, colors == ['chocolate',' bisque', 'cadetblue'])


plt.title('model ')
# Out:
#   File "C:\Users\sinja\AppData\Local\Temp\ipykernel_20672\1974032438.py", line 4
#     df_origin['count'].plot(kind = 'pie', figsize = (7, 5), autopct = '%1.1f%%', startangle = 10, colors == ['chocolate',' bisque', 'cadetblue'])
#                                                                                                                                                 ^
# SyntaxError: positional argument follows keyword argument

# %%
fig = plt.figure(figsize = (15, 5))

ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.boxplot(x=[df[df['origin']==1]['mpg'],
df[df['origin']==2]['mpg'],
df[df['origin']==3]['mpg']], labels = ['USA', 'EU', 'JPN'])

ax2.boxplot(x=[df[df['origin']==1]['mpg'],
df[df['origin']==2]['mpg'],
df[df['origin']==3]['mpg']], labels = ['USA', 'EU', 'JPN'], vert = False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a771ed01c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a771ed0760>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a771ec2eb0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1a771ed0d00>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1a771ed0fd0>,
# ...
#  'means': []}

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20672\2534368572.py in <module>
# ----> 1 df[df[origin]==1]['mpg'],
#       2 df[df[origin]==2]['mpg'],
#       3 df[df[origin]==3]['mpg'],
#
# NameError: name 'origin' is not defined
