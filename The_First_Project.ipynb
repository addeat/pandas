# %%
import pandas as pd
import matplotlib as plt
import numpy as np

# %%
df = pd.read_csv('./서울특별시_강남구_주차장정보_20230208.csv', header = None, encoding = 'cp949')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21412\1627057626.py in <module>
# ----> 1 df = pd.read_csv('./서울특별시_강남구_주차장정보_20230208.csv', header = None, encoding = 'utf-8')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df
# Out:
#               0          1      2      3                        4        5   \
# 0        주차장관리번호       주차장명  주차장구분  주차장유형                 소재지도로명주소  소재지지번주소
# 1   122-1-000005    언주로147길     공영     노상    서울특별시 강남구 언주로 147길 18      NaN
# 2   122-1-000006    도산대로45길     공영     노상       서울특별시 강남구 도산대로 323      NaN
# 3   122-1-000007    언주로171길     공영     노상        서울특별시 강남구 언주로 857      NaN
# 4   122-1-000008    선릉로146길     공영     노상        서울특별시 강남구 선릉로 742      NaN
# 5   122-1-000009    선릉로132길     공영     노상        서울특별시 강남구 학동로 405      NaN
# 6   122-1-000010    테헤란로64길     공영     노상       서울특별시 강남구 테헤란로 412      NaN
# 7   122-1-000011    영동대로85길     공영     노상       서울특별시 강남구 테헤란로 504      NaN
# 8   122-1-000012    테헤란로26길     공영     노상       서울특별시 강남구 테헤란로 152      NaN
# 9   122-1-000013     논현로28길     공영     노상      서울특별시 강남구 논현로28길 25      NaN
# 10  122-1-000014   영동대로106길     공영     노상     서울특별시 강남구 영동대로106길33      NaN
# ...
