# %%
import pandas as pd
import matplotlib.pyplot as plt


from matplotlib import font_manager,rc


plt.rc('font', family='Malgun Gothic')

#font_path='./malgun.ttf'
#font_name=font_manager.FontProperties(fname=font_path).get_name()

#rc('font',family=font_name)

# %%
df=pd.read_excel('시도별 전출입 인구수.xlsx', engine='openpyxl',header=0)

# %%
df
# Out:
#      전출지별     전입지별      1970      1971      1972      1973      1974  \
# 0    전출지별     전입지별  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1      전국       전국   4046536   4210164   3687938   4860418   5297969
# 2     NaN    서울특별시   1742813   1671705   1349333   1831858   2050392
# 3     NaN    부산광역시    448577    389797    362202    482061    680984
# 4     NaN    대구광역시         -         -         -         -         -
# ..    ...      ...       ...       ...       ...       ...       ...
# 320   NaN     전라북도       139       202       141       210       219
# 321   NaN     전라남도       631       965       857       952      1133
# 322   NaN     경상북도       374       619       468       576       625
# 323   NaN     경상남도       474       479       440       571      1208
# 324   NaN  제주특별자치도      9290     12427     12210     16158     19580
#
#          1975      1976      1977  ...      2008      2009      2010  \
# ...

# %%
df.shape
# Out:
# (325, 50)

# %%
df=df.fillna(method='ffill')

# %%
df
# Out:
#         전출지별     전입지별      1970      1971      1972      1973      1974  \
# 0       전출지별     전입지별  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1         전국       전국   4046536   4210164   3687938   4860418   5297969
# 2         전국    서울특별시   1742813   1671705   1349333   1831858   2050392
# 3         전국    부산광역시    448577    389797    362202    482061    680984
# 4         전국    대구광역시         -         -         -         -         -
# ..       ...      ...       ...       ...       ...       ...       ...
# 320  제주특별자치도     전라북도       139       202       141       210       219
# 321  제주특별자치도     전라남도       631       965       857       952      1133
# 322  제주특별자치도     경상북도       374       619       468       576       625
# 323  제주특별자치도     경상남도       474       479       440       571      1208
# 324  제주특별자치도  제주특별자치도      9290     12427     12210     16158     19580
#
#          1975      1976      1977  ...      2008      2009      2010  \
# ...

# %%
df.columns
# Out:
# Index(['전출지별', '전입지별', '1970', '1971', '1972', '1973', '1974', '1975', '1976',
#        '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017'],
#       dtype='object')

# %%
mask=(df['전출지별']=='서울특별시')&(df['전입지별']!='서울특별시')

# %%
df_seoul=df[mask]

# %%
df.head(40)
# Out:
#      전출지별     전입지별      1970      1971      1972      1973      1974  \
# 0    전출지별     전입지별  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1      전국       전국   4046536   4210164   3687938   4860418   5297969
# 2      전국    서울특별시   1742813   1671705   1349333   1831858   2050392
# 3      전국    부산광역시    448577    389797    362202    482061    680984
# 4      전국    대구광역시         -         -         -         -         -
# 5      전국    인천광역시         -         -         -         -         -
# 6      전국    광주광역시         -         -         -         -         -
# 7      전국    대전광역시         -         -         -         -         -
# 8      전국    울산광역시         -         -         -         -         -
# 9      전국  세종특별자치시         -         -         -         -         -
# 10     전국      경기도    452060    533375    418045    542224    579194
# 11     전국      강원도    160959    183964    161637    241663    184385
# 12     전국     충청북도    100041    111901     99573    122988    125958
# ...

# %%
mask.head(40)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37    False
# 38    False
# 39    False
# dtype: bool

# %%
df_seoul
# Out:
#      전출지별     전입지별     1970     1971     1972     1973     1974     1975  \
# 19  서울특별시       전국  1448985  1419016  1210559  1647268  1819660  2937093
# 21  서울특별시    부산광역시    11568    11130    11768    16307    22220    27515
# 22  서울특별시    대구광역시        -        -        -        -        -        -
# 23  서울특별시    인천광역시        -        -        -        -        -        -
# 24  서울특별시    광주광역시        -        -        -        -        -        -
# 25  서울특별시    대전광역시        -        -        -        -        -        -
# 26  서울특별시    울산광역시        -        -        -        -        -        -
# 27  서울특별시  세종특별자치시        -        -        -        -        -        -
# 28  서울특별시      경기도   130149   150313    93333   143234   149045   253705
# 29  서울특별시      강원도     9352    12885    13561    16481    15479    27837
# 30  서울특별시     충청북도     6700     9457    10853    12617    11786    21073
# 31  서울특별시     충청남도    15954    18943    23406    27139    25509    51205
# ...

# %%
df_seoul=df_seoul.drop(['전출지별'],axis=1)

# %%
df_seoul
# Out:
#        전입지별     1970     1971     1972     1973     1974     1975     1976  \
# 19       전국  1448985  1419016  1210559  1647268  1819660  2937093  2495620
# 21    부산광역시    11568    11130    11768    16307    22220    27515    23732
# 22    대구광역시        -        -        -        -        -        -        -
# 23    인천광역시        -        -        -        -        -        -        -
# 24    광주광역시        -        -        -        -        -        -        -
# 25    대전광역시        -        -        -        -        -        -        -
# 26    울산광역시        -        -        -        -        -        -        -
# 27  세종특별자치시        -        -        -        -        -        -        -
# 28      경기도   130149   150313    93333   143234   149045   253705   202276
# 29      강원도     9352    12885    13561    16481    15479    27837    25927
# 30     충청북도     6700     9457    10853    12617    11786    21073    18029
# ...

# %%
df_seoul=df_seoul.rename({'전입지별':'전입지'},axis=1)

# %%
df_seoul
# Out:
#         전입지     1970     1971     1972     1973     1974     1975     1976  \
# 19       전국  1448985  1419016  1210559  1647268  1819660  2937093  2495620
# 21    부산광역시    11568    11130    11768    16307    22220    27515    23732
# 22    대구광역시        -        -        -        -        -        -        -
# 23    인천광역시        -        -        -        -        -        -        -
# 24    광주광역시        -        -        -        -        -        -        -
# 25    대전광역시        -        -        -        -        -        -        -
# 26    울산광역시        -        -        -        -        -        -        -
# 27  세종특별자치시        -        -        -        -        -        -        -
# 28      경기도   130149   150313    93333   143234   149045   253705   202276
# 29      강원도     9352    12885    13561    16481    15479    27837    25927
# 30     충청북도     6700     9457    10853    12617    11786    21073    18029
# ...

# %%
df_seoul=df_seoul.set_index('전입지')

# %%
df_seoul
# Out:
#             1970     1971     1972     1973     1974     1975     1976  \
# 전입지
# 전국       1448985  1419016  1210559  1647268  1819660  2937093  2495620
# 부산광역시      11568    11130    11768    16307    22220    27515    23732
# 대구광역시          -        -        -        -        -        -        -
# 인천광역시          -        -        -        -        -        -        -
# 광주광역시          -        -        -        -        -        -        -
# 대전광역시          -        -        -        -        -        -        -
# 울산광역시          -        -        -        -        -        -        -
# 세종특별자치시        -        -        -        -        -        -        -
# 경기도       130149   150313    93333   143234   149045   253705   202276
# 강원도         9352    12885    13561    16481    15479    27837    25927
# 충청북도        6700     9457    10853    12617    11786    21073    18029
# 충청남도       15954    18943    23406    27139    25509    51205    41447
# ...

# %%
sr_one=df_seoul.loc['경기도']

# %%
sr_one
# Out:
# 1970    130149
# 1971    150313
# 1972     93333
# 1973    143234
# 1974    149045
# 1975    253705
# 1976    202276
# 1977    207722
# 1978    237684
# 1979    278411
# 1980    297539
# 1981    252073
# 1982    320174
# 1983    400875
# 1984    352238
# 1985    390265
# 1986    412535
# 1987    405220
# 1988    415174
# 1989    412933
# 1990    473889
# 1991    384714
# 1992    428344
# 1993    502584
# 1994    542204
# 1995    599411
# 1996    520566
# 1997    495454
# 1998    407050
# 1999    471841
# 2000    435573
# 2001    499575
# 2002    516765
# 2003    457656
# 2004    400206
# 2005    414621
# 2006    449632
# 2007    431637
# 2008    412408
# 2009    398282
# 2010    410735
# 2011    373771
# 2012    354135
# 2013    340801
# 2014    332785
# 2015    359337
# 2016    370760
# 2017    342433
# Name: 경기도, dtype: object

# %%
plt.plot(sr_one.index,sr_one.values)

# %%
plt.style.use('ggplot')

plt.figure(figsize=(14,5))
plt.xticks(rotation=45)

plt.plot(sr_one.index,sr_one.values,marker='o',markersize=5)

plt.title('서울->경기 인구 이동')
plt.xlabel('기간')
plt.ylabel('이동 인구수')

plt.show()

# %%
fig=plt.figure(figsize=(10,10))

ax1=fig.add_subplot(2,1,1)
ax2=fig.add_subplot(2,1,2)

ax1.plot(sr_one,'o',markersize=10)
ax2.plot(sr_one,marker='o',markerfacecolor='green',markersize=10,
        color='olive',linewidth=2,label='서울->경기')

ax2.legend(loc='best')

ax1.set_ylim(50000,800000)
ax2.set_ylim(50000,800000)


ax1.set_xticklabels(sr_one.index,rotation=75)
ax2.set_xticklabels(sr_one.index,rotation=75)


plt.show()
# Out:
# C:\Users\sinja\AppData\Local\Temp\ipykernel_10260\1117316657.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(sr_one.index,rotation=75)
# C:\Users\sinja\AppData\Local\Temp\ipykernel_10260\1117316657.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(sr_one.index,rotation=75)

# %%
fig=plt.figure(figsize=(20,5))
ax=fig.add_subplot(1,1,1)

ax.plot(sr_one,marker='o',markerfacecolor='orange',markersize=10,
        color='olive',linewidth=2,label='서울->경기')

ax.legend(loc='best')

ax.set_ylim(50000,800000)

ax.set_title('서울->경기 인구 이동')

ax.set_xticklabels(sr_one.index,rotation=75)

ax.tick_params(axis="x",labelsize=10)
ax.tick_params(axis="y",labelsize=10)



plt.show()
# Out:
# C:\Users\sinja\AppData\Local\Temp\ipykernel_10260\2109460460.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(sr_one.index,rotation=75)

# %%
df_seoul
# Out:
#             1970     1971     1972     1973     1974     1975     1976  \
# 전입지
# 전국       1448985  1419016  1210559  1647268  1819660  2937093  2495620
# 부산광역시      11568    11130    11768    16307    22220    27515    23732
# 대구광역시          -        -        -        -        -        -        -
# 인천광역시          -        -        -        -        -        -        -
# 광주광역시          -        -        -        -        -        -        -
# 대전광역시          -        -        -        -        -        -        -
# 울산광역시          -        -        -        -        -        -        -
# 세종특별자치시        -        -        -        -        -        -        -
# 경기도       130149   150313    93333   143234   149045   253705   202276
# 강원도         9352    12885    13561    16481    15479    27837    25927
# 충청북도        6700     9457    10853    12617    11786    21073    18029
# 충청남도       15954    18943    23406    27139    25509    51205    41447
# ...

# %%
col_years=list(map(str,range(1970,2017+1)))
df_3=df_seoul.loc[['충청남도','경상북도','강원도'],col_years]

plt.style.use('ggplot')

fig=plt.figure(figsize=(20,5))
ax=fig.add_subplot(1,1,1)

ax.plot(col_years,df_3.loc['충청남도',:],marker='o',markerfacecolor='green',
       markersize=10, color='olive', linewidth=2, label='서울->충남')

ax.plot(col_years,df_3.loc['경상북도',:],marker='o',markerfacecolor='blue',
       markersize=10, color='skyblue', linewidth=2, label='서울->경북')

ax.plot(col_years,df_3.loc['강원도',:],marker='o',markerfacecolor='red',
       markersize=10, color='magenta',linewidth=2, label='서울->강원')

ax.legend(loc='best')

ax.set_title('서울->충남, 경북, 강원 인구 이동', size=20)

ax.set_xlabel('기간',size=12)
ax.set_ylabel('이동 인구수',size=12)



ax.tick_params(axis="x",labelsize=10)
ax.tick_params(axis="y",labelsize=5)





plt.show()

# %%
df_3
# Out:
#        1970   1971   1972   1973   1974   1975   1976   1977   1978   1979  \
# 전입지
# 충청남도  15954  18943  23406  27139  25509  51205  41447  43993  48091  45388
# 경상북도  11868  16459  22073  27531  26902  46177  40376  41155  42940  43565
# 강원도    9352  12885  13561  16481  15479  27837  25927  25415  26700  27599
#
#       ...   2008   2009   2010   2011   2012   2013   2014   2015   2016  \
# 전입지   ...
# 충청남도  ...  27458  24889  24522  24723  22269  21486  21473  22299  21741
# 경상북도  ...  15425  16569  16042  15818  15191  14420  14456  15113  14236
# 강원도   ...  23668  23331  22736  23624  22332  20601  21173  22659  21590
#
#        2017
# 전입지
# 충청남도  21020
# 경상북도  12464
# 강원도   21016
#
# [3 rows x 48 columns]

# %%
col_years=list(map(str,range(1970,2017+1)))

df_4=df_seoul.loc[['충청남도','경상북도','강원도','전라남도'],col_years]

df_4
# Out:
#        1970   1971   1972   1973   1974   1975   1976   1977   1978   1979  \
# 전입지
# 충청남도  15954  18943  23406  27139  25509  51205  41447  43993  48091  45388
# 경상북도  11868  16459  22073  27531  26902  46177  40376  41155  42940  43565
# 강원도    9352  12885  13561  16481  15479  27837  25927  25415  26700  27599
# 전라남도  10513  16755  20157  22160  21314  46610  46251  43430  44624  47934
#
#       ...   2008   2009   2010   2011   2012   2013   2014   2015   2016  \
# 전입지   ...
# 충청남도  ...  27458  24889  24522  24723  22269  21486  21473  22299  21741
# 경상북도  ...  15425  16569  16042  15818  15191  14420  14456  15113  14236
# 강원도   ...  23668  23331  22736  23624  22332  20601  21173  22659  21590
# 전라남도  ...  16601  17468  16429  15974  14765  14187  14591  14598  13065
#
#        2017
# 전입지
# 충청남도  21020
# 경상북도  12464
# 강원도   21016
# 전라남도  12426
#
# [4 rows x 48 columns]

# %%
plt.rcParams['axes.unicode_minus'] = False

plt.style.use('ggplot')

fig=plt.figure(figsize=(20,10))

ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)
ax4=fig.add_subplot(2,2,4)

ax1.plot(col_years,df_4.loc['충청남도',:],marker='o',markerfacecolor='green',
        markersize=10,color='olive',linewidth=2,label='서울->충남')

ax2.plot(col_years,df_4.loc['경상북도',:],marker='D',markerfacecolor='blue',
        markersize=8,color='skyblue',linewidth=2.5,label='서울->경북')

ax3.plot(col_years,df_4.loc['강원도',:],marker='+',markerfacecolor='red',
        markersize=13,color='black',linewidth=1.5,label='서울->강원')

ax4.plot(col_years,df_4.loc['전라남도',:],marker='o',markerfacecolor='orange',
        markersize=10,color='yellow',linewidth=2,label='서울->전라남도')

ax1.legend(loc='best')
ax2.legend(loc='upper left')
ax3.legend(loc='lower left')
ax4.legend(loc='lower right')

ax1.set_title('서울->충남 인구 이동',size=15)
ax2.set_title('서울->경북 인구 이동',size=15)
ax3.set_title('서울->강원 인구 이동',size=15)
ax4.set_title('서울->전남 인구 이동',size=15)

ax1.set_ylim(5000,80000)
ax2.set_ylim(5000,80000)
ax3.set_ylim(5000,80000)
ax4.set_ylim(5000,80000)

ax1.set_xticklabels(col_years,rotation=90)
ax2.set_xticklabels(col_years,rotation=90)
ax3.set_xticklabels(col_years,rotation=90)
ax4.set_xticklabels(col_years,rotation=90)


plt.show()
# Out:
# C:\Users\sinja\AppData\Local\Temp\ipykernel_10260\4240104481.py:39: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(col_years,rotation=90)
# C:\Users\sinja\AppData\Local\Temp\ipykernel_10260\4240104481.py:40: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(col_years,rotation=90)
# C:\Users\sinja\AppData\Local\Temp\ipykernel_10260\4240104481.py:41: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(col_years,rotation=90)
# C:\Users\sinja\AppData\Local\Temp\ipykernel_10260\4240104481.py:42: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax4.set_xticklabels(col_years,rotation=90)

# %%
df_4=df_seoul.loc[['충청남도','경상북도','강원도','전라남도'],col_years]
df_4
# Out:
#        1970   1971   1972   1973   1974   1975   1976   1977   1978   1979  \
# 전입지
# 충청남도  15954  18943  23406  27139  25509  51205  41447  43993  48091  45388
# 경상북도  11868  16459  22073  27531  26902  46177  40376  41155  42940  43565
# 강원도    9352  12885  13561  16481  15479  27837  25927  25415  26700  27599
# 전라남도  10513  16755  20157  22160  21314  46610  46251  43430  44624  47934
#
#       ...   2008   2009   2010   2011   2012   2013   2014   2015   2016  \
# 전입지   ...
# 충청남도  ...  27458  24889  24522  24723  22269  21486  21473  22299  21741
# 경상북도  ...  15425  16569  16042  15818  15191  14420  14456  15113  14236
# 강원도   ...  23668  23331  22736  23624  22332  20601  21173  22659  21590
# 전라남도  ...  16601  17468  16429  15974  14765  14187  14591  14598  13065
#
#        2017
# 전입지
# 충청남도  21020
# 경상북도  12464
# 강원도   21016
# 전라남도  12426
#
# [4 rows x 48 columns]

# %%
df_4
# Out:
#        1970   1971   1972   1973   1974   1975   1976   1977   1978   1979  \
# 전입지
# 충청남도  15954  18943  23406  27139  25509  51205  41447  43993  48091  45388
# 경상북도  11868  16459  22073  27531  26902  46177  40376  41155  42940  43565
# 강원도    9352  12885  13561  16481  15479  27837  25927  25415  26700  27599
# 전라남도  10513  16755  20157  22160  21314  46610  46251  43430  44624  47934
#
#       ...   2008   2009   2010   2011   2012   2013   2014   2015   2016  \
# 전입지   ...
# 충청남도  ...  27458  24889  24522  24723  22269  21486  21473  22299  21741
# 경상북도  ...  15425  16569  16042  15818  15191  14420  14456  15113  14236
# 강원도   ...  23668  23331  22736  23624  22332  20601  21173  22659  21590
# 전라남도  ...  16601  17468  16429  15974  14765  14187  14591  14598  13065
#
#        2017
# 전입지
# 충청남도  21020
# 경상북도  12464
# 강원도   21016
# 전라남도  12426
#
# [4 rows x 48 columns]

# %%
df_4_t=df_4.T

# %%
df_4_t
# Out:
# 전입지    충청남도   경상북도    강원도   전라남도
# 1970  15954  11868   9352  10513
# 1971  18943  16459  12885  16755
# 1972  23406  22073  13561  20157
# 1973  27139  27531  16481  22160
# 1974  25509  26902  15479  21314
# 1975  51205  46177  27837  46610
# 1976  41447  40376  25927  46251
# 1977  43993  41155  25415  43430
# 1978  48091  42940  26700  44624
# 1979  45388  43565  27599  47934
# 1980  54480  48839  32858  56251
# 1981  51369  30928  32116  57645
# 1982  48834  27440  31013  55408
# 1983  55344  29601  31308  57737
# 1984  50318  26842  30470  52779
# 1985  49520  26297  29911  52629
# 1986  47888  26221  28489  41082
# 1987  48678  27844  28699  42667
# 1988  49038  26235  26691  40695
# 1989  31707  22374  26394  36188
# 1990  29993  21490  26591  35589
# 1991  28211  19054  25208  29925
# 1992  26600  19342  25215  27258
# 1993  25958  17604  23244  25554
# 1994  22293  16067  21384  21737
# 1995  26501  17064  24987  24100
# 1996  27159  16899  25221  23790
# ...

# %%
plt.style.use('ggplot')
df_4_t.plot(kind='area',stacked=False)

plt.show()

# %%
plt.style.use('ggplot')
df_4_t.plot(kind='area',stacked=True)

plt.show()

# %%
ax=df_4_t.plot(kind='area',stacked=True,figsize=(15,5))

ax.set_title('서울->타시도 인구 이동',size=20,color='brown',weight='bold')
ax.set_ylabel('이동 인구수')
ax.set_xlabel('기간')
ax.legend(loc='best', fontsize = 10)

plt.show()

# %%
col_years = list(map(str, range(2010, 2018)))
df_4 = df_seoul.loc[['충청남도', '경상북도', '강원도', '전라남도'], col_years]
print(df_4)
df_4 = df_4.transpose()

plt.style.use('ggplot')
df_4.index = df_4.index.map(int)
df_4.plot(kind = 'bar', figsize = (20, 10), width=0.7, color = ['orange', 'green', 'skyblue', 'blue'])  
                      # figsize(가로길이,세로길이)
plt.legend(bbox_to_anchor = (1.05, 1), fontsize = 8)
plt.ylabel('이동 인구 수')
plt.xlabel('기간')
plt.ylim(5000, 30000)
plt.title('서울 -> 타도시 인구이동', size = 15)
plt
plt.show()
df_4
# Out:
#        2010   2011   2012   2013   2014   2015   2016   2017
# 전입지
# 충청남도  24522  24723  22269  21486  21473  22299  21741  21020
# 경상북도  16042  15818  15191  14420  14456  15113  14236  12464
# 강원도   22736  23624  22332  20601  21173  22659  21590  21016
# 전라남도  16429  15974  14765  14187  14591  14598  13065  12426
# 전입지    충청남도   경상북도    강원도   전라남도
# 2010  24522  16042  22736  16429
# 2011  24723  15818  23624  15974
# 2012  22269  15191  22332  14765
# 2013  21486  14420  20601  14187
# 2014  21473  14456  21173  14591
# 2015  22299  15113  22659  14598
# 2016  21741  14236  21590  13065
# 2017  21020  12464  21016  12426

# %%
col_years = list(map(str, range(2010, 2018)))
df_4 = df_seoul.loc[['충청남도', '경상북도', '강원도', '전라남도'], col_years]
print(df_4)
# 만약 각 년도별 데이터값의 합을 구하고싶으면  각열의 값들을 더해주면 된다.

df_4['합계'] = df_4.sum(axis = 1)
# axis = 1 열단위 순서 , axis = 0 행단위 순서

df_total = df_4[['합계']].sort_values(by = '합계', ascending = True)  # sort_values 를 통해 정렬(by를 통해, 오름차순 T , F)
plt.style.use('ggplot')

df_total.plot(kind = 'barh', color = 'cornflowerblue', width = 0.5 , figsize = (10, 5))

plt.title('서울 -> 타시도 인구 이동')
plt.ylabel('전입지')
plt.xlabel('이동 인구 수')

plt.show()
# Out:
#        2010   2011   2012   2013   2014   2015   2016   2017
# 전입지
# 충청남도  24522  24723  22269  21486  21473  22299  21741  21020
# 경상북도  16042  15818  15191  14420  14456  15113  14236  12464
# 강원도   22736  23624  22332  20601  21173  22659  21590  21016
# 전라남도  16429  15974  14765  14187  14591  14598  13065  12426
